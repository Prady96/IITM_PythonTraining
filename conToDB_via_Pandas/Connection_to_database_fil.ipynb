# %%
import pandas as pd
import sqlalchemy

# %% [raw]
# Standard --- mysql+pymysql
# username -- root
# password -- root
# link -- localhost
# database name -- csvTest
# ## test database name -- data_2
#
# Refernce Link used : https://docs.sqlalchemy.org/en/latest/core/connections.html

# %%
# engine = sqlalchemy.create_engine('mysql+pymysql://root:root@phpmyadmin.lan/csvTest')
engine = sqlalchemy.create_engine('mysql+pymysql://root:root@localhost/data_2')

# %%
# examples to get data from the database
df = pd.read_sql_table("table_name_for_df", engine)
df
# Out:
#     index                                                  0              1  \
# 0       0                                                        31/03/2017
# 1       1                           Balance sheet [Abstract]
# 2       2                                  Assets [Abstract]
# 3       3                      Non-current assets [Abstract]
# 4       4                      Property, plant and equipment      53,514.57
# 5       5                           Capital work-in-progress       3,167.94
# 6       6                            Other intangible assets         929.43
# 7       7                Intangible assets under development         234.36
# 8       8            Non-current financial assets [Abstract]
# 9       9                            Non-current investments              0
# 10     10                                 Loans, non-current         111.34
# 11     11                 Total non-current financial assets         111.34
# ...

# %%
## only to read a set of columns
# filtering columns from data
df = pd.read_sql_table("table_name_for_df", engine,columns=['1','2'])
df
# Out:
#                 1              2
# 0      31/03/2017     31/03/2016
# 1
# 2
# 3
# 4       53,514.57      48,595.62
# 5        3,167.94       5,322.92
# 6          929.43       1,054.62
# 7          234.36         535.01
# 8
# 9               0              0
# 10         111.34         111.57
# 11         111.34         111.57
# 12  (A)  4,809.59     (B)  4,352
# 13         290.87       1,250.44
# 14       63,058.1      61,222.18
# 15
# 16   (D)  5,288.9  (E)  4,878.28
# 17
# 18       3,649.96       3,366.99
# 19              0              0
# 20       4,055.57          43.72
# 21      25,803.91      29,153.27
# 22          78.15          29.57
# 23      33,587.59      32,593.55
# 24       1,846.13       1,371.91
# 25      40,722.62      38,843.74
# 26    1,03,780.72    1,00,065.92
# 27
# 28
# 29
# 30          7,700          7,700
# 31      73,563.15      69,109.71
# 32      81,263.15      76,809.71
# 33      81,263.15      76,809.71
# 34
# 35
# 36
# ...

# %%
## Using sql query method to query data
query = '''
select * from table_name_for_df
'''
df = pd.read_sql_query(query, engine)
df
# Out:
#     index                                                  0              1  \
# 0       0                                                        31/03/2017
# 1       1                           Balance sheet [Abstract]
# 2       2                                  Assets [Abstract]
# 3       3                      Non-current assets [Abstract]
# 4       4                      Property, plant and equipment      53,514.57
# 5       5                           Capital work-in-progress       3,167.94
# 6       6                            Other intangible assets         929.43
# 7       7                Intangible assets under development         234.36
# 8       8            Non-current financial assets [Abstract]
# 9       9                            Non-current investments              0
# 10     10                                 Loans, non-current         111.34
# 11     11                 Total non-current financial assets         111.34
# ...

# %%
df[df['1'].str.contains("Total liabilities")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/django-apps/freshInstall/fresh/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-67a2cff57cbc> in <module>
# ...

# %%
# # renaming a columns
# df.rename(columns = {
#     '0': 'Abstract Information',
#     '1': '2017 Dates'
# }, inplace = True)
# df

# %%
## Writing data from df to sql
df = pd.read_csv("foo.csv")
df
# Out:
#                                            Unnamed: 0     31/03/2017  \
# 0                            Balance sheet [Abstract]            NaN
# 1                                   Assets [Abstract]            NaN
# 2                       Non-current assets [Abstract]            NaN
# 3                       Property, plant and equipment      53,514.57
# 4                            Capital work-in-progress       3,167.94
# 5                             Other intangible assets         929.43
# 6                 Intangible assets under development         234.36
# 7             Non-current financial assets [Abstract]            NaN
# 8                             Non-current investments              0
# 9                                  Loans, non-current         111.34
# 10                 Total non-current financial assets         111.34
# 11                          Deferred tax assets (net)  (A)  4,809.59
# 12                           Other non-current assets         290.87
# ...

# %%
## Copy all the 20 data points
df_test = df[df['Unnamed: 0'].str.contains("Total liabilities")]
df_test
## Reference Link https://stackoverflow.com/a/22846437/7999665
# Out:
#            Unnamed: 0 31/03/2017 31/03/2016 31/03/2015
# 52  Total liabilities  22,517.57  23,256.21  18,436.63

# %%
## Converting columns into rows
df_multi = pd.melt(df_test, id_vars=['Unnamed: 0'],
                  var_name='Dates', value_name="value")

## Refernce Link https://stackoverflow.com/a/28654127/7999665

# %%
print(df_multi)
# Out:
#           Unnamed: 0       Dates      value
# 0  Total liabilities  31/03/2017  22,517.57
# 1  Total liabilities  31/03/2016  23,256.21
# 2  Total liabilities  31/03/2015  18,436.63

# %%
## Appending data to the database table
df_multi.to_sql( 
    name = 'newTestingTable',
    con = engine,
    index = True,
    if_exists = 'append'
)

# %%
# df.set_index(['Unnamed: 0', ])

# %%
df.to_sql( 
    name = 'newTestingTable',
    con = engine,
    index = True,
    if_exists = 'append'
)

# %%
df
# Out:
#                                            Unnamed: 0     31/03/2017  \
# 0                            Balance sheet [Abstract]            NaN
# 1                                   Assets [Abstract]            NaN
# 2                       Non-current assets [Abstract]            NaN
# 3                       Property, plant and equipment      53,514.57
# 4                            Capital work-in-progress       3,167.94
# 5                             Other intangible assets         929.43
# 6                 Intangible assets under development         234.36
# 7             Non-current financial assets [Abstract]            NaN
# 8                             Non-current investments              0
# 9                                  Loans, non-current         111.34
# 10                 Total non-current financial assets         111.34
# 11                          Deferred tax assets (net)  (A)  4,809.59
# 12                           Other non-current assets         290.87
# ...

# %%
## Using sql query method to query data
query = '''
select * from finalTesting
'''
df3 = pd.read_sql_query(query, engine)
df3['years'] = '2017'
df3
# Out:
#     index                                         Unnamed: 0     31/03/2017  \
# 0       0                           Balance sheet [Abstract]           None
# 1       1                                  Assets [Abstract]           None
# 2       2                      Non-current assets [Abstract]           None
# 3       3                      Property, plant and equipment      53,514.57
# 4       4                           Capital work-in-progress       3,167.94
# 5       5                            Other intangible assets         929.43
# 6       6                Intangible assets under development         234.36
# 7       7            Non-current financial assets [Abstract]           None
# 8       8                            Non-current investments              0
# 9       9                                 Loans, non-current         111.34
# 10     10                 Total non-current financial assets         111.34
# ...

# %%
# df3.pivot_table(columns='Unnamed: 0',
#                         values='31/03/2017',
#                         index = 'years'
#                         )
df2017 = df3.set_index(['years','Unnamed: 0']).unstack().reset_index()
df2017
# Out:
#            years             index                           \
# Unnamed: 0       Assets [Abstract] Balance sheet [Abstract]
# 0           2017                 1                        0
#
#                                                         \
# Unnamed: 0 Borrowings, current Borrowings, non-current
# 0                           44                      36
#
#                                                                \
# Unnamed: 0 Capital work-in-progress Cash and cash equivalents
# 0                                 4                        19
#
#                                                                           \
# Unnamed: 0 Current assets [Abstract] Current financial assets [Abstract]
# 0                                 14                                  16
#
#                                                      \
# Unnamed: 0 Current financial liabilities [Abstract]
# 0                                                43
#
# ...

# %%
df2017.to_sql( 
    name = '2017TestingTable',
    con = engine,
    index = True,
    if_exists = 'replace'
)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~/django-apps/freshInstall/fresh/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~/django-apps/freshInstall/fresh/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#
# ~/django-apps/freshInstall/fresh/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ...

# %%
dfD1 = pd.read_sql_table("Years", engine)
dfD1

# %%
dfD2 = pd.read_sql_table("newTestingTable", engine)
dfD2
# Out:
#      index                                         Unnamed: 0     31/03/2017  \
# 0        0                           Balance sheet [Abstract]           None
# 1        1                                  Assets [Abstract]           None
# 2        2                      Non-current assets [Abstract]           None
# 3        3                      Property, plant and equipment      53,514.57
# 4        4                           Capital work-in-progress       3,167.94
# 5        5                            Other intangible assets         929.43
# 6        6                Intangible assets under development         234.36
# 7        7            Non-current financial assets [Abstract]           None
# 8        8                            Non-current investments              0
# 9        9                                 Loans, non-current         111.34
# 10      10                 Total non-current financial assets         111.34
# ...

# %%
dfM = pd.merge(dfD1,dfD2,how='outer', on='index')
dfM
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-000d6597948e> in <module>
# ----> 1 dfM = pd.merge(dfD1,dfD2,how='outer', on='index')
#       2 dfM
#
# NameError: name 'dfD1' is not defined

# %%
df2017 = dfM.set_index(['YearsIntable','Unnamed: 0']).unstack().reset_index()
df2017
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-6047f1849de4> in <module>
# ----> 1 df2017 = dfM.set_index(['YearsIntable','Unnamed: 0']).unstack().reset_index()
#       2 df2017
#
# NameError: name 'dfM' is not defined
